# %% [markdown]
# <h1 style="text-align: center;">COMP40610 Information Visualization Project</h1>
#
# ### Student Name: Ayush Poojari
# ### Student Number: 24214170

# %% [markdown]
# #### `Importing Libraries`

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### `Reading original dataset from tidytuesday`

# %%
ol = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-07-27/olympics.csv')

# %% [markdown]
# #### `Information about dataset`

# %%
ol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      271116 non-null  int64
#  1   name    271116 non-null  object
#  2   sex     271116 non-null  object
#  3   age     261642 non-null  float64
#  4   height  210945 non-null  float64
#  5   weight  208241 non-null  float64
#  6   team    271116 non-null  object
#  7   noc     271116 non-null  object
#  8   games   271116 non-null  object
#  9   year    271116 non-null  int64
#  10  season  271116 non-null  object
#  11  city    271116 non-null  object
#  12  sport   271116 non-null  object
#  13  event   271116 non-null  object
#  14  medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# `Insights: 15 features/columns in the dataset`
# - `5 Quantitative features/columns: id,age,height,weight and year`
# - `10 Categorical features/columns: name,sex,team,noc,games,season,city,sport,event and medal`
# - `Memory Usage: 31.0+ MB`
#
# `📌 NOTE: Year feature/column needs to be converted datetime if needed`

# %% [markdown]
# #### `Describing the dataset`

# %%
ol.describe().T
# Out:
#            count          mean           std     min      25%      50%  \
# id      271116.0  68248.954396  39022.286345     1.0  34643.0  68205.0
# age     261642.0     25.556898      6.393561    10.0     21.0     24.0
# height  210945.0    175.338970     10.518462   127.0    168.0    175.0
# weight  208241.0     70.702393     14.348020    25.0     60.0     70.0
# year    271116.0   1978.378480     29.877632  1896.0   1960.0   1988.0
#
#               75%       max
# id      102097.25  135571.0
# age         28.00      97.0
# height     183.00     226.0
# weight      79.00     214.0
# year      2002.00    2016.0

# %% [markdown]
# `📌 Insights: We can get overall picture about quantitative data in the dataset`
# - `id: Starts from 1 upto 135571`
# - `age: Average age 28.0 years, minimum 10.0 years and maximum 97.0 years`
# - `height: Average height 183.0 cm, minimum 127.0 cm and maximum 226.0 cm`
# - `weight: Average weight 79.0 kg, minimum 24.0 kg and maximum 214.0 kg`

# %% [markdown]
# #### `Viewing the dataset:`

# %%
ol.head(14)
# Out:
#     id                      name sex   age  height  weight            team  \
# 0    1                 A Dijiang   M  24.0   180.0    80.0           China
# 1    2                  A Lamusi   M  23.0   170.0    60.0           China
# 2    3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0   United States
# ...

# %%
ol.tail(14)
# Out:
#             id                          name sex   age  height  weight  \
# 271102  135563     Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563     Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
# 271104  135564  Yevgeny Aleksandrovich Zykov   M  22.0   172.0    65.0
# 271105  135565      Fernando scar Zylberberg   M  23.0   168.0    76.0
# 271106  135565      Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107  135566    James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109  135567  Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271113  135570                      Piotr ya   M  27.0   176.0    59.0
# ...

# %% [markdown]
# #### `Dimension of dataset:`

# %%
print(f'The dataset has {ol.shape[0]} rows/tuples and {ol.shape[1]} features/columns')
# Out:
# The dataset has 271116 rows/tuples and 15 features/columns

# %%
start_year = ol['year'].min()
end_year = ol['year'].max()
print(f"The dataset covers years from {start_year} to {end_year}.")
# Out:
# The dataset covers years from 1896 to 2016.

# %% [markdown]
# ### `📌 Data Cleaning and Preprocessing`

# %% [markdown]
# #### `Checking for missing values in rows/tuples`

# %%
ol.isna().sum()
# Out:
# id             0
# name           0
# sex            0
# age         9474
# height     60171
# weight     62875
# team           0
# noc            0
# games          0
# year           0
# season         0
# city           0
# sport          0
# event          0
# medal     231333
# dtype: int64

# %%
ol.isnull().sum()
# Out:
# id             0
# name           0
# sex            0
# age         9474
# height     60171
# weight     62875
# team           0
# noc            0
# games          0
# year           0
# season         0
# city           0
# sport          0
# event          0
# medal     231333
# dtype: int64

# %% [markdown]
# #### `There is following number of missing values:`
# - age	9474
# - height	60171
# - weight	62875
# - medal	231333
#
# #### `📌 NOTE: Medals has maximum NA because it represents no medals we can set it "No Medal"`

# %% [markdown]
# #### `Dropping missing values from age, height and weight features/columns`

# %%
ol = ol.dropna(subset=['age', 'height', 'weight'], how='any')

# %%
ol.shape
# Out:
# (206165, 15)

# %%
ol.isna().sum()
# Out:
# id             0
# name           0
# sex            0
# age            0
# height         0
# weight         0
# team           0
# noc            0
# games          0
# year           0
# season         0
# city           0
# sport          0
# event          0
# medal     175984
# dtype: int64

# %%
ol.isnull().sum()
# Out:
# id             0
# name           0
# sex            0
# age            0
# height         0
# weight         0
# team           0
# noc            0
# games          0
# year           0
# season         0
# city           0
# sport          0
# event          0
# medal     175984
# dtype: int64

# %% [markdown]
# `We can see there are no missing values in the age, height and weight features/columns`

# %% [markdown]
# #### `Checking for duplicate rows/tuples in dataset`

# %%
ol[ol.duplicated()].head(13)
# Out:
#             id                        name sex   age  height  weight  \
# 87975    44600                Gavin Hadden   M  44.0   188.0    77.0
# 87976    44600                Gavin Hadden   M  44.0   188.0    77.0
# 87977    44600                Gavin Hadden   M  44.0   188.0    77.0
# 92832    47034        Louis Hechenbleikner   M  38.0   178.0    67.0
# 92833    47034        Louis Hechenbleikner   M  38.0   178.0    67.0
# 92834    47034        Louis Hechenbleikner   M  38.0   178.0    67.0
# 92835    47034        Louis Hechenbleikner   M  38.0   178.0    67.0
# 151807   76185           Alexandre Maspoli   M  48.0   170.0    81.0
# 212857  106878     Maurice Auguste Schills   M  20.0   188.0    83.0
# 216070  108451        Edgar Isaac Seligman   M  61.0   174.0    80.0
# 222410  111729  Jerzy Walerian Skolimowski   M  24.0   150.0    59.0
# 222411  111729  Jerzy Walerian Skolimowski   M  24.0   150.0    59.0
# 222412  111729  Jerzy Walerian Skolimowski   M  24.0   150.0    59.0
#
# ...

# %%
ol[ol.duplicated()].shape
# Out:
# (13, 15)

# %%
ol = ol.drop_duplicates()

# %%
ol.shape
# Out:
# (206152, 15)

# %% [markdown]
# `Dropped all duplicate rows and tuples`

# %% [markdown]
# ### `📌 In Medal Glory: Olympic Medallists and Winning Nations (1896–2016) dashboard 📊`
#
# > `I am visualizing metrics and statistics only for olympic medallist and top winning nations`
#
# > `The required step do so is to filters out only medal winning players`
#
# `Dropped columns where medal is NA which means "No medal"`

# %%
ol.dropna(subset=['medal'],inplace=True)

# %%
ol.shape
# Out:
# (30181, 15)

# %% [markdown]
# #### `Dimension of dataset is reduced to (30181,15)`

# %%
ol.head(12)
# Out:
#     id                      name sex   age  height  weight     team  noc  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 50  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland  FIN
# 60  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
# 61  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
# 63  20        Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway  NOR
# 64  20        Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway  NOR
# 67  20        Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway  NOR
# 73  20        Kjetil Andr Aamodt   M  30.0   176.0    85.0   Norway  NOR
#
# ...

# %% [markdown]
# #### `Making dataset consistent`

# %%
ol.columns = ol.columns.str.lower().str.replace(' ', '_')

# %%
ol.columns
# Out:
# Index(['id', 'name', 'sex', 'age', 'height', 'weight', 'team', 'noc', 'games',
#        'year', 'season', 'city', 'sport', 'event', 'medal'],
#       dtype='object')

# %% [markdown]
# #### `Checking for outliers or erroneous values`

# %%
ol.describe().T
# Out:
#           count          mean           std     min      25%      50%  \
# id      30181.0  70225.949604  38839.720551    16.0  37494.0  69771.0
# age     30181.0     25.429012      5.049684    13.0     22.0     25.0
# height  30181.0    177.642358     10.924188   136.0    170.0    178.0
# weight  30181.0     73.753554     15.004992    28.0     63.0     73.0
# year    30181.0   1988.005964     22.718451  1896.0   1976.0   1992.0
#
#              75%       max
# id      104111.0  135563.0
# age         28.0      66.0
# height     185.0     223.0
# weight      83.0     182.0
# year      2006.0    2016.0

# %%
ol = ol[(ol['age'] >= 10) & (ol['age'] < 120)]

# %%
ol = ol[(ol['height'] < 300)]

# %%
ol.shape
# Out:
# (30181, 15)

# %%
ol.head(14)
# Out:
#     id                      name sex   age  height  weight     team  noc  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 50  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland  FIN
# 60  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
# 61  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
# 63  20        Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway  NOR
# 64  20        Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway  NOR
# 67  20        Kjetil Andr Aamodt   M  22.0   176.0    85.0   Norway  NOR
# 73  20        Kjetil Andr Aamodt   M  30.0   176.0    85.0   Norway  NOR
# ...

# %%
ol.tail(14)
# Out:
#             id                                 name sex   age  height  weight  \
# 271013  135522      Klaas Erik "Klaas-Erik" Zwering   M  23.0   189.0    80.0
# 271015  135523       Ronald Ferdinand "Ron" Zwerver   M  25.0   200.0    93.0
# 271016  135523       Ronald Ferdinand "Ron" Zwerver   M  29.0   200.0    93.0
# 271019  135525                       Martin Zwicker   M  29.0   175.0    64.0
# 271032  135535            Claudia Antoinette Zwiers   F  22.0   181.0    78.0
# 271046  135544                   Krzysztof Zwoliski   M  21.0   175.0    70.0
# 271048  135545                      Henk Jan Zwolle   M  27.0   197.0    93.0
# 271049  135545                      Henk Jan Zwolle   M  31.0   197.0    93.0
# 271076  135553  Galina Ivanovna Zybina (-Fyodorova)   F  21.0   168.0    80.0
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# ...

# %% [markdown]
# #### `📌 Feature Transformation: Deriving features/columns`

# %% [markdown]
# #### `BMI from height and weight`

# %%
ol['bmi'] = ol['weight'] / (ol['height'] / 100) ** 2

# %%
ol.head(8)
# Out:
#     id                      name sex   age  height  weight     team  noc  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 50  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland  FIN
# 60  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
# 61  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
#
#           games  year  season         city          sport  \
# 40  2014 Winter  2014  Winter        Sochi     Ice Hockey
# 41  1948 Summer  1948  Summer       London     Gymnastics
# 42  1948 Summer  1948  Summer       London     Gymnastics
# 44  1948 Summer  1948  Summer       London     Gymnastics
# ...

# %%
ol['ratio'] = ol['height'] / ol['weight']

# %%
ol.head(8)
# Out:
#     id                      name sex   age  height  weight     team  noc  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 50  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland  FIN
# 60  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
# 61  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
#
#           games  year  season         city          sport  \
# 40  2014 Winter  2014  Winter        Sochi     Ice Hockey
# 41  1948 Summer  1948  Summer       London     Gymnastics
# 42  1948 Summer  1948  Summer       London     Gymnastics
# 44  1948 Summer  1948  Summer       London     Gymnastics
# ...

# %%
def bmi_category(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif 18.5 <= bmi < 24.9:
        return 'Normal weight'
    elif 25 <= bmi < 29.9:
        return 'Overweight'
    else:
        return 'Obese'

ol['bmi_category'] = ol['bmi'].apply(bmi_category)

# %%
ol.head(8)
# Out:
#     id                      name sex   age  height  weight     team  noc  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 50  17   Paavo Johannes Aaltonen   M  32.0   175.0    64.0  Finland  FIN
# 60  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
# 61  20        Kjetil Andr Aamodt   M  20.0   176.0    85.0   Norway  NOR
#
#           games  year  season         city          sport  \
# 40  2014 Winter  2014  Winter        Sochi     Ice Hockey
# 41  1948 Summer  1948  Summer       London     Gymnastics
# 42  1948 Summer  1948  Summer       London     Gymnastics
# 44  1948 Summer  1948  Summer       London     Gymnastics
# ...

# %% [markdown]
# ####  `Derived features/columns: bmi, bmi_category and ratio`

# %%
ol['sex'] = ol['sex'].str.capitalize()
ol['team'] = ol['team'].str.capitalize()
ol['season'] = ol['season'].str.capitalize()
ol['city'] = ol['city'].str.capitalize()
ol['sport'] = ol['sport'].str.capitalize()
ol['medal'] = ol['medal'].str.capitalize()
ol['bmi_category'] = ol['bmi_category'].str.capitalize()

# %%
ol.head(4)
# Out:
#     id                      name sex   age  height  weight     team  noc  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           games  year  season    city       sport  \
# 40  2014 Winter  2014  Winter   Sochi  Ice hockey
# 41  1948 Summer  1948  Summer  London  Gymnastics
# 42  1948 Summer  1948  Summer  London  Gymnastics
# 44  1948 Summer  1948  Summer  London  Gymnastics
#
#                                      event   medal        bmi     ratio  \
# 40             Ice Hockey Men's Ice Hockey  Bronze  25.106333  2.164706
# 41  Gymnastics Men's Individual All-Around  Bronze  20.897959  2.734375
# 42        Gymnastics Men's Team All-Around    Gold  20.897959  2.734375
# ...

# %%
ol['age'] = pd.to_numeric(ol['age'], errors='coerce')
ol['height'] = pd.to_numeric(ol['height'], errors='coerce')
ol['weight'] = pd.to_numeric(ol['weight'], errors='coerce')
ol['year'] = pd.to_numeric(ol['year'], errors='coerce')

# %%
ol.head(4)
# Out:
#     id                      name sex   age  height  weight     team  noc  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           games  year  season    city       sport  \
# 40  2014 Winter  2014  Winter   Sochi  Ice hockey
# 41  1948 Summer  1948  Summer  London  Gymnastics
# 42  1948 Summer  1948  Summer  London  Gymnastics
# 44  1948 Summer  1948  Summer  London  Gymnastics
#
#                                      event   medal        bmi     ratio  \
# 40             Ice Hockey Men's Ice Hockey  Bronze  25.106333  2.164706
# 41  Gymnastics Men's Individual All-Around  Bronze  20.897959  2.734375
# 42        Gymnastics Men's Team All-Around    Gold  20.897959  2.734375
# ...

# %% [markdown]
# #### `Changing to appropriate datatype`

# %%
ol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30181 entries, 40 to 271103
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            30181 non-null  int64
#  1   name          30181 non-null  object
#  2   sex           30181 non-null  object
#  3   age           30181 non-null  float64
#  4   height        30181 non-null  float64
#  5   weight        30181 non-null  float64
#  6   team          30181 non-null  object
#  7   noc           30181 non-null  object
#  8   games         30181 non-null  object
#  9   year          30181 non-null  int64
#  10  season        30181 non-null  object
#  11  city          30181 non-null  object
#  12  sport         30181 non-null  object
#  13  event         30181 non-null  object
#  14  medal         30181 non-null  object
#  15  bmi           30181 non-null  float64
#  16  ratio         30181 non-null  float64
#  17  bmi_category  30181 non-null  object
# ...

# %%
ol['sex'] = ol['sex'].astype('category')
ol['team'] = ol['team'].astype('category')
ol['noc'] = ol['noc'].astype('category')
ol['games'] = ol['games'].astype('category')
ol['season'] = ol['season'].astype('category')
ol['sport'] = ol['sport'].astype('category')
ol['event'] = ol['event'].astype('category')
ol['medal'] = ol['medal'].astype('category')
ol['bmi_category'] = ol['bmi_category'].astype('category')

# %%
ol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30181 entries, 40 to 271103
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            30181 non-null  int64
#  1   name          30181 non-null  object
#  2   sex           30181 non-null  category
#  3   age           30181 non-null  float64
#  4   height        30181 non-null  float64
#  5   weight        30181 non-null  float64
#  6   team          30181 non-null  category
#  7   noc           30181 non-null  category
#  8   games         30181 non-null  category
#  9   year          30181 non-null  int64
#  10  season        30181 non-null  category
#  11  city          30181 non-null  object
#  12  sport         30181 non-null  category
#  13  event         30181 non-null  category
#  14  medal         30181 non-null  category
#  15  bmi           30181 non-null  float64
#  16  ratio         30181 non-null  float64
# ...

# %% [markdown]
# #### `📌 Saving the cleaned datafame as a csv file: Olympics.csv`

# %%
ol.to_csv('olympics.csv', index=False)

# %% [markdown]
# <h1 style="text-align: center;">END OF NOTEBOOK</h1>
